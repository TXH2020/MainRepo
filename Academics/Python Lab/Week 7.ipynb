# %%
x=input("Enter a number")
l=[1,2]
d={1:2,2:3}
try:
    if(x=='1'):print(xyz)
    elif(x=='2'):
      print(l[3])
    elif(x=='3'):
      print(d[3])
    elif(x=='4'):
      print(2/0)
except NameError:
      print("NameError")
except IndexError:
      print("IndexError")
except KeyError:
      print("KeyError")
except ZeroDivisionError:
      print("ZeroDivisionError")
# Out:
# Enter a number1
# NameError

# %%
x=input("Enter a number")
l=[1,2]
d={1:2,2:3}
try:
    if(x=='1'):
      print(xyz)
    elif(x=='2'):
      print(l[3])
    elif(x=='3'):
      print(d[3])
    elif(x=='4'):
      print(2/0)
except NameError:
      print("NameError")
except IndexError:
      print("IndexError")
except KeyError:
      print("KeyError")
except ZeroDivisionError:
      print("ZeroDivisionError")
finally:
  print("This block of code will execute anyways")
# Out:
# Enter a number2
# IndexError
# This block of code will execute anyways

# %%
import ast
l=[]
try:
 for i in range(5):
  l.append(int(input("Enter a no.")))
except ValueError:
  raise ValueError("Entered a non integer")
else:
  x=sum(l)/len(l)
  print(x)
# Out:
# Enter a no.f
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cff4705ddba2> in <module>()
#       4  for i in range(5):
# ----> 5   l.append(int(input("Enter a no.")))
#       6 except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'f'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cff4705ddba2> in <module>()
#       5   l.append(int(input("Enter a no.")))
#       6 except ValueError:
# ----> 7   raise ValueError("Entered a non integer")
#       8 else:
#       9   x=sum(l)/len(l)
#
# ValueError: Entered a non integer

# %%
x=int(input("Enter age"))
if(x<1 or x>150):
  raise Exception("Age is not proper(>150 or <1)")
elif(x>1 and x<18):
  print("Not eligible to vote")
else:
  print("Eligible to vote")
# Out:
# Enter age-1
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-da124080ebb7> in <module>()
#       1 x=int(input("Enter age"))
#       2 if(x<1 or x>150):
# ----> 3   raise Exception("Age is not proper(>150 or <1)")
#       4 elif(x>1 and x<18):
#       5   print("Not eligible to vote")
#
# Exception: Age is not proper(>150 or <1)

# %%
import math
def MySqrt(n):
  if(n<0):
    raise Exception("Cannot take square root of negative number")
  else:
    print("Square root of %d is %f"%(n,math.sqrt(n)))
MySqrt(-1)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-e4a67854c16b> in <module>()
#       5   else:
#       6     print("Square root of %d is %f"%(n,math.sqrt(n)))
# ----> 7 MySqrt(-1)
#
# <ipython-input-9-e4a67854c16b> in MySqrt(n)
#       2 def MySqrt(n):
#       3   if(n<0):
# ----> 4     raise Exception("Cannot take square root of negative number")
#       5   else:
#       6     print("Square root of %d is %f"%(n,math.sqrt(n)))
#
# Exception: Cannot take square root of negative number

# %%
class BankAccount:
    def __init__(self,CustName,AccountNumber,Balance,TypeOfAccount,Address):
        self.CustName=CustName
        self.AccountNumber=AccountNumber
        self.Balance=Balance
        self.TypeOfAccount=TypeOfAccount
        self.Address=Address
    def withdraw(self,money):
        if(self.Balance-money<0):
            raise Exception('Insufficient balance.Transaction failed')
        self.Balance=self.Balance-money
    def deposit(self,money):
        if(money<0):
          raise Exception("Negative amount cannot be deposited")
        else:
          self.Balance+=money
    def displayDetails(self):
        print("Customer Name=",self.CustName)
        print("Account Number=",self.AccountNumber)
        print("Balance=",self.Balance)
        print("Type Of Account=",self.TypeOfAccount)
        print("Address=",self.Address)

obj1=BankAccount("DKS",'BF33',100000000,'Deposit','Bangalore')
obj1.withdraw(10000000)
obj1.deposit(1000)
obj1.displayDetails()
# Out:
# Customer Name= DKS
# Account Number= BF33
# Balance= 90001000
# Type Of Account= Deposit
# Address= Bangalore
